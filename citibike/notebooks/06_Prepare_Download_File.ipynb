# %%
files = dbutils.fs.ls(
    "/Volumes/citibike/default/layers/gold/gold_rides_export/"
)

csv_file = [f.path for f in files if f.path.endswith(".csv")][0]

dbutils.fs.cp(
    csv_file,
    "/Volumes/citibike/default/layers/gold/gold_rides.csv",
    True
)
# Out:
# True
