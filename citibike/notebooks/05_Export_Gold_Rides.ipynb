# %%
gold_df = spark.read.format("delta").load(
    "/Volumes/citibike/default/layers/gold/gold_rides"
)

gold_df.coalesce(1).write \
    .mode("overwrite") \
    .option("header", True) \
    .csv("/Volumes/citibike/default/layers/gold/gold_rides_export")

# %%
display(
    dbutils.fs.ls(
        "/Volumes/citibike/default/layers/gold/gold_rides_export/"
    )
)
